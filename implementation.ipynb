# %%
from swap import InterestRateSwap

# %%
IRS = InterestRateSwap(notional = 10000, fixed = 0.345, floating = 0.31, 
                 maturity = '2024-09-22', frequency = 'Annual', daycount = '30/360', valuation = '2014-07-09', 
                 compounding = 'Continuous'
                )

print(IRS)
# Out:
# Interest Rate Swap with notional: 10000, fixed rate: 0.345, floating rate: 0.31, maturity date: 2024-09-22, frequency: Annual, day count convention: 30/360, valuation date: 2014-07-09, compounding method: Continuous

# %%
IRS.fixedleg()
# Out:
#          Date       Time  Fixed Rate  Payment  Discount  Present Value
# 0  2014-09-22   0.202778       0.345   3450.0  0.999943    3449.804955
# 1  2015-09-22   1.202778       0.345   3450.0  0.997619    3441.784798
# 2  2016-09-22   2.202778       0.345   3450.0  0.986534    3403.543791
# 3  2017-09-22   3.202778       0.345   3450.0  0.967113    3336.539262
# 4  2018-09-24   4.208333       0.345   3450.0  0.942041    3250.042032
# 5  2019-09-23   5.205556       0.345   3450.0  0.914122    3153.720653
# 6  2020-09-22   6.202778       0.345   3450.0  0.884782    3052.497555
# 7  2021-09-22   7.202778       0.345   3450.0  0.854931    2949.510885
# 8  2022-09-22   8.202778       0.345   3450.0  0.825241    2847.082319
# 9  2023-09-22   9.202778       0.345   3450.0  0.796058    2746.399017
# 10 2024-09-23  10.205556       1.345  13450.0  0.767498   10322.846687

# %%
IRS.floatleg()
# Out:
#          Date       Time  Floating Rate       Payment  Discount  Present Value
# 0  2014-09-22   0.202778       0.312328   3123.275214  0.999943    3123.098641
# 1  2015-09-22   1.202778       0.321173   3211.729930  0.997619    3204.082100
# 2  2016-09-22   2.202778       0.329883   3298.830596  0.986534    3254.409969
# 3  2017-09-22   3.202778       0.336108   3361.081537  0.967113    3250.545076
# 4  2018-09-24   4.208333       0.340173   3401.729016  0.942041    3204.568779
# 5  2019-09-23   5.205556       0.342716   3427.162342  0.914122    3132.844249
# 6  2020-09-22   6.202778       0.344321   3443.207711  0.884782    3046.487860
# 7  2021-09-22   7.202778       0.345345   3453.446327  0.854931    2952.457256
# 8  2022-09-22   8.202778       0.346004   3460.041170  0.825241    2855.368706
# 9  2023-09-22   9.202778       0.346434   3464.342614  0.796058    2757.816565
# 10 2024-09-23  10.205556       1.346718  13467.184301  0.767498   10336.035602

# %%
IRS.plotcashflows()

# %%
IRS.plotyieldcurve()

# %%
IRS.plotdiscountcurve()

# %%
IRS.plotforwardcurve()

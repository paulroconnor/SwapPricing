# %%
from swap import InterestRateSwap

# %%
IRS = InterestRateSwap(notional = 10000, fixed = 0.05, floating = 0.03, 
                 maturity = '2024-09-22', frequency = 'Monthly', daycount = '30/360', valuation = '2024-06-13', 
                 compounding = 'Continuous'
                )

print(IRS)
# Out:
# Interest Rate Swap with notional: 10000, fixed rate: 0.05, floating rate: 0.03, maturity date: 2024-09-22, frequency: Monthly, day count convention: 30/360, valuation date: 2024-06-13, compounding method: Continuous

# %%
IRS.fixedleg()
# Out:
#         Date      Time  Fixed Rate  Payment  Discount  Present Value
# 0 2024-06-22  0.025000        0.05    500.0  0.998643     499.321575
# 1 2024-07-22  0.108333        0.05    500.0  0.994084     497.042209
# 2 2024-08-22  0.191667        0.05    500.0  0.989534     494.766980
# 3 2024-09-22  0.275000        1.05  10500.0  0.985048   10343.006989

# %%
IRS.floatleg()
# Out:
#         Date      Time  Floating Rate       Payment  Discount  Present Value
# 0 2024-06-22  0.025000       0.080395    803.949875  0.998643     802.859036
# 1 2024-07-22  0.108333       0.079496    794.961021  0.994084     790.258363
# 2 2024-08-22  0.191667       0.078534    785.339382  0.989534     777.119989
# 3 2024-09-22  0.275000       1.077573  10775.730313  0.985048   10614.614661

# %%
IRS.plotyieldcurve()

# %%
IRS.plotdiscountcurve()

# %%
IRS.plotforwardcurve()
